# %% [markdown]
# # Point-by-point mapping notebook
# __Written by Haixing Fang, Jon Wright and James Ball__
# __Date: 21/02/2025__

# %% [markdown]
# This notebook will try to perform a point-by-point index of the 2D peaks you segmented.
# The point-by-point results (usually saved to a .txt file in the sample PROCESSED_DATA folder) are multi-valued (we can find multiple UBIs at each map voxel).
# You can view the results of the point-by-point process 'live' by running the next notebook (pbp_2_visualise).
# That notebook will also allow you to save a single-valued version of the pbp map to H5, ParaView XDMF and MTEX CTF.
# The UBIs we find from the PBP index should have reasonably accurate orientations, but the strains are likely to be poor.
# To get much better strains, slightly better orientations and possibly better grain shapes, you should run pbp_3_refinement
# Then run 4_visualise to convert the refinement results to an accurate single-valued map with good strains.

# %%
import os

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

# %%
exec(open('/data/id11/nanoscope/install_ImageD11_from_git.py').read())

# %%
# this cell is tagged with 'parameters'
# to view the tag, select the cell, then find the settings gear icon (right or left sidebar) and look for Cell Tags

# python environment stuff
PYTHONPATH = setup_ImageD11_from_git( ) # ( os.path.join( os.environ['HOME'],'Code'), 'ImageD11_git' )

# dataset file to import
dset_path = 'si_cube_test/processed/Si_cube/Si_cube_S3DXRD_nt_moves_dty/Si_cube_S3DXRD_nt_moves_dty_dataset.h5'

# which phase to index
phase_str = 'Si'

# filter the columnfile to discard weak peaks
minpkint = 5

# point-by-point parameters
hkl_tol = 0.025
fpks = 0.9
ds_tol = 0.004
etacut = 0.1
ifrac = 5e-3
y0 = 0.0
symmetry = "cubic"
foridx = [0, 1, 3, 5, 7]
forgen = [1, 5, 7]
uniqcut = 0.85
use_cluster = False

# EXPERTS: Can specify par_file as a parameter if you want
par_file = None
# Out:
# # Setting path via:
# sys.path.insert(0, /home/esrf/james1997a/Code/ImageD11 )
# # Running from: /home/esrf/james1997a/Code/ImageD11/ImageD11/__init__.py

# %%
# Parameters
par_file = "/data/id11/inhouse2/test_data_3DXRD/S3DXRD/FeAu/pars/pars.json"
phase_str = "Fe"
minpkint = 5
hkl_tol = 0.03
fpks = 30
ds_tol = 0.008
etacut = 0.1
ifrac = 0.002
y0 = -16.0
symmetry = "cubic"
foridx = [0, 1, 3, 5, 7]
forgen = [1, 5, 7]
uniqcut = 0.85
use_cluster = False
PYTHONPATH = "../"
dset_path = "/data/id11/inhouse2/test_data_3DXRD/S3DXRD/FeAu/PROCESSED_DATA/20250221_JADB/pbp_route/FeAu_0p5_tR_nscope/FeAu_0p5_tR_nscope_top_200um/FeAu_0p5_tR_nscope_top_200um_dataset.h5"

# %%
import numpy as np
from matplotlib import pyplot as plt

import ImageD11.sinograms.point_by_point
import ImageD11.sinograms.dataset
import ImageD11.columnfile

import ImageD11.nbGui.nb_utils as utils

# %matplotlib ipympl

# %% [markdown]
# # Load data
# ## Dataset

# %%
ds = ImageD11.sinograms.dataset.load(dset_path)
print(ds)
# Out:
# dataroot = "/data/id11/inhouse2/test_data_3DXRD/S3DXRD/FeAu/RAW_DATA"
# analysisroot = "/data/id11/inhouse2/test_data_3DXRD/S3DXRD/FeAu/PROCESSED_DATA/20250221_JADB/pbp_route"
# sample = "FeAu_0p5_tR_nscope"
# dset = "top_200um"
# shape = ( 275, 1448)
# # scans 275 from 1.1 to 275.1

# %% [markdown]
# ## Parameters
# Specify the path to your parameter file

# %%
if par_file is None:
    par_file = os.path.join(ds.analysisroot, 'pars.json')
ds.parfile = par_file
ds.save()

# %% [markdown]
# ## Phases
# If the parameter file was a json, we can access the unit cells via `ds.phases.unitcells`

# %%
ds.phases = ds.get_phases_from_disk()
ds.phases.unitcells
# Out:
# {'Au': Au | [ 4.005  4.005  4.005 90.    90.    90.   ] | 225,
#  'Fe': Fe | [ 2.8694  2.8694  2.8694 90.     90.     90.    ] | 229,
#  'CeO2': CeO2 | [ 5.41143  5.41143  5.41143 90.      90.      90.     ] | F}

# %%
ucell = ds.phases.unitcells[phase_str]
print(ucell)
# Out:
# Fe | [ 2.8694  2.8694  2.8694 90.     90.     90.    ] | 229

# %% [markdown]
# ## Peaks

# %%
cf_2d = ds.get_cf_2d()
ds.update_colfile_pars(cf_2d, phase_name=phase_str)
if not os.path.exists(ds.col2dfile):
    # save the 2D peaks to file so we don't have to spatially correct them again
    ImageD11.columnfile.colfile_to_hdf(cf_2d, ds.col2dfile)

# %%
# filter the columnfile to discard weak peaks

cf_2d.filter(cf_2d.Number_of_pixels > minpkint)

# %%
cosine_tol=np.cos(np.radians(90 - ds.ostep))

pbp_object = ImageD11.sinograms.point_by_point.PBP(ds.parfile,
                                                    ds,
                                                    hkl_tol=hkl_tol,
                                                    fpks=fpks,
                                                    ds_tol=ds_tol,
                                                    etacut=etacut,
                                                    ifrac=ifrac,
                                                    cosine_tol=cosine_tol,
                                                    y0=y0,
                                                    symmetry=symmetry,
                                                    foridx=foridx,
                                                    forgen=forgen,
                                                    uniqcut=uniqcut,
                                                    phase_name=phase_str)

# make icolf filename phase-aware
icolf_filename = ds.icolfile.replace('.h5', f'_{phase_str}.h5')
grains_filename = ds.pbpfile.replace('.txt', f'_{phase_str}.txt')

pbp_object.setpeaks(cf_2d, icolf_filename=icolf_filename)
# Out:
# 0 0.4929 (1, 0, 1) 12 371623 used, sum_intensity> 530.316
# 1 0.6970 (2, 0, 0) 6 159974 used, sum_intensity> 287.286
# 2 0.8537 (2, 1, 1) 24 skipped
# 3 0.9857 (0, 2, 2) 12 201851 used, sum_intensity> 179.43
# 4 1.1021 (1, 3, 0) 24 skipped
# 5 1.2073 (2, 2, 2) 8 110602 used, sum_intensity> 121.664
# 6 1.3040 (2, 3, 1) 48 skipped
# 7 1.3940 (4, 0, 0) 6 116911 used, sum_intensity> 63.298
# 8 1.4786 (1, 4, 1) 36 skipped
# 9 1.5586 (4, 2, 0) 24 skipped
# 10 1.6346 (2, 3, 3) 24 skipped
# 11 1.7073 (2, 4, 2) 24 skipped
# 12 1.7770 (1, 4, 3) 72 skipped
# 13 1.9088 (1, 2, 5) 48 skipped
# 14 1.9714 (4, 4, 0) 12 skipped
# 15 2.0321 (3, 4, 3) 48 skipped
# 16 2.0910 (6, 0, 0) 30 skipped
# 17 2.1483 (6, 1, 1) 72 skipped
# 18 2.2041 (2, 6, 0) 24 skipped
# Using for indexing: 960961 npks, minpks, forgen 44 30 [1, 5, 7]

# %%
fig, ax = pbp_object.iplot(skip=1)  # increase skip to make plot faster
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Indexing

# %%
if use_cluster:
    bash_script_path = utils.prepare_pbp_bash(pbp_object, PYTHONPATH, minpkint)
    utils.slurm_submit_and_wait(bash_script_path, 15)
else:
    pbp_object.point_by_point(grains_filename, loglevel=3)
# Out:
# {'cosine_tol': 0.002181658028916515,
#  'ds_tol': 0.008,
#  'forgen': [1, 5, 7],
#  'hkl_tol': 0.03,
#  'hmax': 4,
#  'minpks': 30,
#  'uniqcut': 0.85,
#  'y0': -16.0,
#  'ymin': -274.00012223777037,
#  'ystep': 2.000000892246499}
# Done   0.047 %, average grains/point   2.15, 0.551 /s/point, total 22.0 /s
# Done   0.094 %, average grains/point   2.41, 0.280 /s/point, total 22.4 /s
# Done   0.142 %, average grains/point   2.42, 0.189 /s/point, total 22.7 /s
# Done   0.189 %, average grains/point   2.30, 0.143 /s/point, total 22.9 /s
# Done   0.236 %, average grains/point   2.29, 0.115 /s/point, total 23.1 /s
# Done   0.283 %, average grains/point   2.22, 0.097 /s/point, total 23.2 /s
# Done   0.331 %, average grains/point   2.16, 0.083 /s/point, total 23.3 /s
# Done   0.378 %, average grains/point   2.24, 0.073 /s/point, total 23.5 /s
# Done   0.425 %, average grains/point   2.27, 0.066 /s/point, total 23.6 /s
# Done   0.472 %, average grains/point   2.25, 0.059 /s/point, total 23.7 /s
# Done   0.520 %, average grains/point   2.21, 0.054 /s/point, total 23.9 /s
# Done   0.567 %, average grains/point   2.22, 0.050 /s/point, total 24.0 /s
# Done   0.614 %, average grains/point   2.20, 0.046 /s/point, total 24.1 /s
# Done   0.661 %, average grains/point   2.19, 0.043 /s/point, total 24.2 /s
# Done   0.709 %, average grains/point   2.17, 0.041 /s/point, total 24.4 /s
# Done   0.756 %, average grains/point   2.17, 0.038 /s/point, total 24.5 /s
# Done   0.803 %, average grains/point   2.16, 0.036 /s/point, total 24.6 /s
# Done   0.850 %, average grains/point   2.16, 0.034 /s/point, total 24.7 /s
# Done   0.897 %, average grains/point   2.16, 0.033 /s/point, total 24.9 /s
# Done   0.945 %, average grains/point   2.15, 0.031 /s/point, total 25.0 /s
# Done   0.992 %, average grains/point   2.16, 0.030 /s/point, total 25.1 /s
# Done   1.039 %, average grains/point   2.16, 0.029 /s/point, total 25.3 /s
# Done   1.086 %, average grains/point   2.19, 0.028 /s/point, total 25.4 /s
# Done   1.134 %, average grains/point   2.16, 0.027 /s/point, total 25.5 /s
# Done   1.181 %, average grains/point   2.17, 0.026 /s/point, total 25.6 /s
# Done   1.228 %, average grains/point   2.17, 0.025 /s/point, total 25.8 /s
# Done   1.275 %, average grains/point   2.17, 0.024 /s/point, total 25.9 /s
# Done   1.323 %, average grains/point   2.17, 0.023 /s/point, total 26.0 /s
# Done   1.370 %, average grains/point   2.15, 0.023 /s/point, total 26.1 /s
# Done   1.417 %, average grains/point   2.16, 0.022 /s/point, total 26.3 /s
# Done   1.464 %, average grains/point   2.16, 0.021 /s/point, total 26.4 /s
# Done   1.512 %, average grains/point   2.14, 0.021 /s/point, total 26.5 /s
# Done   1.559 %, average grains/point   2.14, 0.020 /s/point, total 26.7 /s
# Done   1.606 %, average grains/point   2.15, 0.020 /s/point, total 26.8 /s
# Done   1.653 %, average grains/point   2.14, 0.019 /s/point, total 26.9 /s
# Done   1.700 %, average grains/point   2.14, 0.019 /s/point, total 27.1 /s
# Done   1.748 %, average grains/point   2.14, 0.018 /s/point, total 27.2 /s
# Done   1.795 %, average grains/point   2.13, 0.018 /s/point, total 27.3 /s
# Done   1.842 %, average grains/point   2.14, 0.018 /s/point, total 27.4 /s
# Done   1.889 %, average grains/point   2.14, 0.017 /s/point, total 27.5 /s
# Done   1.937 %, average grains/point   2.14, 0.017 /s/point, total 27.7 /s
# Done   1.984 %, average grains/point   2.14, 0.017 /s/point, total 27.8 /s
# Done   2.031 %, average grains/point   2.14, 0.016 /s/point, total 27.9 /s
# Done   2.078 %, average grains/point   2.14, 0.016 /s/point, total 28.1 /s
# Done   2.126 %, average grains/point   2.15, 0.016 /s/point, total 28.2 /s
# Done   2.173 %, average grains/point   2.15, 0.015 /s/point, total 28.3 /s
# Done   2.220 %, average grains/point   2.15, 0.015 /s/point, total 28.4 /s
# Done   2.267 %, average grains/point   2.15, 0.015 /s/point, total 28.6 /s
# Done   2.315 %, average grains/point   2.14, 0.015 /s/point, total 28.7 /s
# Done   2.362 %, average grains/point   2.14, 0.014 /s/point, total 28.9 /s
# Done   2.409 %, average grains/point   2.13, 0.014 /s/point, total 29.0 /s
# Done   2.456 %, average grains/point   2.14, 0.014 /s/point, total 29.1 /s
# Done   2.504 %, average grains/point   2.12, 0.014 /s/point, total 29.2 /s
# Done   2.551 %, average grains/point   2.12, 0.014 /s/point, total 29.3 /s
# Done   2.598 %, average grains/point   2.12, 0.013 /s/point, total 29.5 /s
# Done   2.645 %, average grains/point   2.12, 0.013 /s/point, total 29.6 /s
# Done   2.692 %, average grains/point   2.12, 0.013 /s/point, total 29.7 /s
# Done   2.740 %, average grains/point   2.12, 0.013 /s/point, total 29.9 /s
# Done   2.787 %, average grains/point   2.12, 0.013 /s/point, total 30.0 /s
# Done   2.834 %, average grains/point   2.12, 0.013 /s/point, total 30.1 /s
# Done   2.881 %, average grains/point   2.11, 0.012 /s/point, total 30.3 /s
# Done   2.929 %, average grains/point   2.11, 0.012 /s/point, total 30.4 /s
# Done   2.976 %, average grains/point   2.11, 0.012 /s/point, total 30.5 /s
# Done   3.023 %, average grains/point   2.10, 0.012 /s/point, total 30.6 /s
# Done   3.070 %, average grains/point   2.10, 0.012 /s/point, total 30.8 /s
# Done   3.118 %, average grains/point   2.10, 0.012 /s/point, total 30.9 /s
# Done   3.165 %, average grains/point   2.10, 0.012 /s/point, total 31.0 /s
# Done   3.212 %, average grains/point   2.11, 0.011 /s/point, total 31.1 /s
# Done   3.259 %, average grains/point   2.10, 0.011 /s/point, total 31.3 /s
# Done   3.307 %, average grains/point   2.10, 0.011 /s/point, total 31.4 /s
# Done   3.354 %, average grains/point   2.10, 0.011 /s/point, total 31.5 /s
# Done   3.401 %, average grains/point   2.09, 0.011 /s/point, total 31.7 /s
# Done   3.448 %, average grains/point   2.09, 0.011 /s/point, total 31.8 /s
# Done   3.495 %, average grains/point   2.09, 0.011 /s/point, total 31.9 /s
# Done   3.543 %, average grains/point   2.09, 0.011 /s/point, total 32.1 /s
# Done   3.590 %, average grains/point   2.09, 0.011 /s/point, total 32.2 /s
# Done   3.637 %, average grains/point   2.09, 0.010 /s/point, total 32.3 /s
# Done   3.684 %, average grains/point   2.09, 0.010 /s/point, total 32.5 /s
# Done   3.732 %, average grains/point   2.09, 0.010 /s/point, total 32.6 /s
# Done   3.779 %, average grains/point   2.09, 0.010 /s/point, total 32.7 /s
# Done   3.826 %, average grains/point   2.10, 0.010 /s/point, total 32.9 /s
# Done   3.873 %, average grains/point   2.09, 0.010 /s/point, total 33.0 /s
# Done   3.921 %, average grains/point   2.09, 0.010 /s/point, total 33.1 /s
# Done   3.968 %, average grains/point   2.09, 0.010 /s/point, total 33.2 /s
# Done   4.015 %, average grains/point   2.09, 0.010 /s/point, total 33.4 /s
# Done   4.062 %, average grains/point   2.09, 0.010 /s/point, total 33.5 /s
# Done   4.110 %, average grains/point   2.09, 0.010 /s/point, total 33.6 /s
# Done   4.157 %, average grains/point   2.09, 0.010 /s/point, total 33.7 /s
# Done   4.204 %, average grains/point   2.09, 0.010 /s/point, total 33.9 /s
# Done   4.251 %, average grains/point   2.09, 0.009 /s/point, total 34.0 /s
# Done   4.298 %, average grains/point   2.09, 0.009 /s/point, total 34.1 /s
# Done   4.346 %, average grains/point   2.09, 0.009 /s/point, total 34.3 /s
# Done   4.393 %, average grains/point   2.09, 0.009 /s/point, total 34.4 /s
# Done   4.440 %, average grains/point   2.09, 0.009 /s/point, total 34.5 /s
# Done   4.487 %, average grains/point   2.10, 0.009 /s/point, total 34.6 /s
# Done   4.535 %, average grains/point   2.09, 0.009 /s/point, total 34.7 /s
# Done   4.582 %, average grains/point   2.09, 0.009 /s/point, total 34.9 /s
# Done   4.629 %, average grains/point   2.09, 0.009 /s/point, total 35.0 /s
# Done   4.676 %, average grains/point   2.09, 0.009 /s/point, total 35.1 /s
# Done   4.724 %, average grains/point   2.09, 0.009 /s/point, total 35.3 /s
# Done   4.771 %, average grains/point   2.08, 0.009 /s/point, total 35.4 /s
# Done   4.818 %, average grains/point   2.08, 0.009 /s/point, total 35.5 /s
# Done   4.865 %, average grains/point   2.08, 0.009 /s/point, total 35.6 /s
# Done   4.913 %, average grains/point   2.08, 0.009 /s/point, total 35.8 /s
# Done   4.960 %, average grains/point   2.08, 0.009 /s/point, total 35.9 /s
# Done   5.007 %, average grains/point   2.08, 0.008 /s/point, total 36.0 /s
# Done   5.054 %, average grains/point   2.08, 0.008 /s/point, total 36.2 /s
# Done   5.101 %, average grains/point   2.08, 0.008 /s/point, total 36.3 /s
# Done   5.149 %, average grains/point   2.08, 0.008 /s/point, total 36.4 /s
# Done   5.196 %, average grains/point   2.08, 0.008 /s/point, total 36.5 /s
# Done   5.243 %, average grains/point   2.09, 0.008 /s/point, total 36.7 /s
# Done   5.290 %, average grains/point   2.09, 0.008 /s/point, total 36.8 /s
# Done   5.338 %, average grains/point   2.09, 0.008 /s/point, total 36.9 /s
# Done   5.385 %, average grains/point   2.08, 0.008 /s/point, total 37.0 /s
# Done   5.432 %, average grains/point   2.09, 0.008 /s/point, total 37.2 /s
# Done   5.479 %, average grains/point   2.09, 0.008 /s/point, total 37.3 /s
# Done   5.527 %, average grains/point   2.09, 0.008 /s/point, total 37.4 /s
# Done   5.574 %, average grains/point   2.09, 0.008 /s/point, total 37.5 /s
# Done   5.621 %, average grains/point   2.09, 0.008 /s/point, total 37.7 /s
# Done   5.668 %, average grains/point   2.09, 0.008 /s/point, total 37.8 /s
# Done   5.716 %, average grains/point   2.09, 0.008 /s/point, total 37.9 /s
# Done   5.763 %, average grains/point   2.09, 0.008 /s/point, total 38.1 /s
# Done   5.810 %, average grains/point   2.09, 0.008 /s/point, total 38.2 /s
# Done   5.857 %, average grains/point   2.09, 0.008 /s/point, total 38.3 /s
# Done   5.905 %, average grains/point   2.09, 0.008 /s/point, total 38.5 /s
# Done   5.952 %, average grains/point   2.08, 0.008 /s/point, total 38.6 /s
# Done   5.999 %, average grains/point   2.08, 0.008 /s/point, total 38.7 /s
# Done   6.046 %, average grains/point   2.08, 0.008 /s/point, total 38.9 /s
# Done   6.093 %, average grains/point   2.08, 0.008 /s/point, total 39.0 /s
# Done   6.141 %, average grains/point   2.08, 0.008 /s/point, total 39.1 /s
# Done   6.188 %, average grains/point   2.08, 0.007 /s/point, total 39.2 /s
# Done   6.235 %, average grains/point   2.08, 0.007 /s/point, total 39.4 /s
# Done   6.282 %, average grains/point   2.08, 0.007 /s/point, total 39.5 /s
# Done   6.330 %, average grains/point   2.08, 0.007 /s/point, total 39.6 /s
# Done   6.377 %, average grains/point   2.08, 0.007 /s/point, total 39.7 /s
# Done   6.424 %, average grains/point   2.09, 0.007 /s/point, total 39.9 /s
# Done   6.471 %, average grains/point   2.08, 0.007 /s/point, total 40.0 /s
# Done   6.519 %, average grains/point   2.08, 0.007 /s/point, total 40.1 /s
# Done   6.566 %, average grains/point   2.08, 0.007 /s/point, total 40.3 /s
# Done   6.613 %, average grains/point   2.08, 0.007 /s/point, total 40.4 /s
# Done   6.660 %, average grains/point   2.08, 0.007 /s/point, total 40.5 /s
# Done   6.708 %, average grains/point   2.08, 0.007 /s/point, total 40.6 /s
# Done   6.755 %, average grains/point   2.08, 0.007 /s/point, total 40.8 /s
# Done   6.802 %, average grains/point   2.08, 0.007 /s/point, total 40.9 /s
# Done   6.849 %, average grains/point   2.08, 0.007 /s/point, total 41.0 /s
# Done   6.896 %, average grains/point   2.08, 0.007 /s/point, total 41.1 /s
# Done   6.944 %, average grains/point   2.08, 0.007 /s/point, total 41.3 /s
# Done   6.991 %, average grains/point   2.08, 0.007 /s/point, total 41.4 /s
# Done   7.038 %, average grains/point   2.08, 0.007 /s/point, total 41.5 /s
# Done   7.085 %, average grains/point   2.08, 0.007 /s/point, total 41.6 /s
# Done   7.133 %, average grains/point   2.07, 0.007 /s/point, total 41.8 /s
# Done   7.180 %, average grains/point   2.07, 0.007 /s/point, total 41.9 /s
# Done   7.227 %, average grains/point   2.08, 0.007 /s/point, total 42.0 /s
# Done   7.274 %, average grains/point   2.08, 0.007 /s/point, total 42.2 /s
# Done   7.322 %, average grains/point   2.08, 0.007 /s/point, total 42.3 /s
# Done   7.369 %, average grains/point   2.08, 0.007 /s/point, total 42.4 /s
# Done   7.416 %, average grains/point   2.08, 0.007 /s/point, total 42.5 /s
# Done   7.463 %, average grains/point   2.08, 0.007 /s/point, total 42.6 /s
# Done   7.511 %, average grains/point   2.08, 0.007 /s/point, total 42.8 /s
# Done   7.558 %, average grains/point   2.08, 0.007 /s/point, total 42.9 /s
# Done   7.605 %, average grains/point   2.08, 0.007 /s/point, total 43.0 /s
# Done   7.652 %, average grains/point   2.08, 0.007 /s/point, total 43.1 /s
# Done   7.699 %, average grains/point   2.08, 0.007 /s/point, total 43.2 /s
# Done   7.747 %, average grains/point   2.08, 0.007 /s/point, total 43.4 /s
# Done   7.794 %, average grains/point   2.08, 0.007 /s/point, total 43.5 /s
# Done   7.841 %, average grains/point   2.08, 0.007 /s/point, total 43.6 /s
# Done   7.888 %, average grains/point   2.08, 0.007 /s/point, total 43.8 /s
# Done   7.936 %, average grains/point   2.08, 0.007 /s/point, total 43.9 /s
# Done   7.983 %, average grains/point   2.08, 0.007 /s/point, total 44.0 /s
# Done   8.030 %, average grains/point   2.08, 0.006 /s/point, total 44.1 /s
# Done   8.077 %, average grains/point   2.08, 0.006 /s/point, total 44.3 /s
# Done   8.125 %, average grains/point   2.08, 0.006 /s/point, total 44.4 /s
# Done   8.172 %, average grains/point   2.08, 0.006 /s/point, total 44.5 /s
# Done   8.219 %, average grains/point   2.07, 0.006 /s/point, total 44.7 /s
# Done   8.266 %, average grains/point   2.07, 0.006 /s/point, total 44.8 /s
# Done   8.314 %, average grains/point   2.07, 0.006 /s/point, total 44.9 /s
# Done   8.361 %, average grains/point   2.07, 0.006 /s/point, total 45.0 /s
# Done   8.408 %, average grains/point   2.07, 0.006 /s/point, total 45.2 /s
# Done   8.455 %, average grains/point   2.07, 0.006 /s/point, total 45.3 /s
# Done   8.502 %, average grains/point   2.07, 0.006 /s/point, total 45.4 /s
# Done   8.550 %, average grains/point   2.07, 0.006 /s/point, total 45.5 /s
# Done   8.597 %, average grains/point   2.07, 0.006 /s/point, total 45.7 /s
# Done   8.644 %, average grains/point   2.07, 0.006 /s/point, total 45.8 /s
# Done   8.691 %, average grains/point   2.07, 0.006 /s/point, total 45.9 /s
# Done   8.739 %, average grains/point   2.08, 0.006 /s/point, total 46.0 /s
# Done   8.786 %, average grains/point   2.08, 0.006 /s/point, total 46.2 /s
# Done   8.833 %, average grains/point   2.08, 0.006 /s/point, total 46.3 /s
# Done   8.880 %, average grains/point   2.08, 0.006 /s/point, total 46.4 /s
# Done   8.928 %, average grains/point   2.08, 0.006 /s/point, total 46.5 /s
# Done   8.975 %, average grains/point   2.07, 0.006 /s/point, total 46.7 /s
# Done   9.022 %, average grains/point   2.07, 0.006 /s/point, total 46.8 /s
# Done   9.069 %, average grains/point   2.07, 0.006 /s/point, total 46.9 /s
# Done   9.117 %, average grains/point   2.07, 0.006 /s/point, total 47.0 /s
# Done   9.164 %, average grains/point   2.08, 0.006 /s/point, total 47.2 /s
# Done   9.211 %, average grains/point   2.07, 0.006 /s/point, total 47.3 /s
# Done   9.258 %, average grains/point   2.07, 0.006 /s/point, total 47.4 /s
# Done   9.306 %, average grains/point   2.08, 0.006 /s/point, total 47.6 /s
# Done   9.353 %, average grains/point   2.07, 0.006 /s/point, total 47.7 /s
# Done   9.400 %, average grains/point   2.08, 0.006 /s/point, total 47.8 /s
# Done   9.447 %, average grains/point   2.07, 0.006 /s/point, total 47.9 /s
# Done   9.494 %, average grains/point   2.08, 0.006 /s/point, total 48.0 /s
# Done   9.542 %, average grains/point   2.08, 0.006 /s/point, total 48.2 /s
# Done   9.589 %, average grains/point   2.08, 0.006 /s/point, total 48.3 /s
# Done   9.636 %, average grains/point   2.08, 0.006 /s/point, total 48.4 /s
# Done   9.683 %, average grains/point   2.08, 0.006 /s/point, total 48.6 /s
# Done   9.731 %, average grains/point   2.08, 0.006 /s/point, total 48.7 /s
# Done   9.778 %, average grains/point   2.08, 0.006 /s/point, total 48.8 /s
# Done   9.825 %, average grains/point   2.08, 0.006 /s/point, total 48.9 /s
# Done   9.872 %, average grains/point   2.09, 0.006 /s/point, total 49.1 /s
# Done   9.920 %, average grains/point   2.09, 0.006 /s/point, total 49.2 /s
# Done   9.967 %, average grains/point   2.08, 0.006 /s/point, total 49.3 /s
# Done  10.014 %, average grains/point   2.08, 0.006 /s/point, total 49.5 /s
# Done  10.061 %, average grains/point   2.08, 0.006 /s/point, total 49.6 /s
# Done  10.109 %, average grains/point   2.08, 0.006 /s/point, total 49.7 /s
# Done  10.156 %, average grains/point   2.08, 0.006 /s/point, total 49.8 /s
# Done  10.203 %, average grains/point   2.08, 0.006 /s/point, total 50.0 /s
# Done  10.250 %, average grains/point   2.08, 0.006 /s/point, total 50.1 /s
# Done  10.297 %, average grains/point   2.08, 0.006 /s/point, total 50.2 /s
# Done  10.345 %, average grains/point   2.08, 0.006 /s/point, total 50.3 /s
# Done  10.392 %, average grains/point   2.08, 0.006 /s/point, total 50.5 /s
# Done  10.439 %, average grains/point   2.08, 0.006 /s/point, total 50.6 /s
# Done  10.486 %, average grains/point   2.08, 0.006 /s/point, total 50.7 /s
# Done  10.534 %, average grains/point   2.08, 0.006 /s/point, total 50.8 /s
# Done  10.581 %, average grains/point   2.08, 0.006 /s/point, total 50.9 /s
# Done  10.628 %, average grains/point   2.08, 0.006 /s/point, total 51.1 /s
# Done  10.675 %, average grains/point   2.08, 0.006 /s/point, total 51.2 /s
# Done  10.723 %, average grains/point   2.08, 0.006 /s/point, total 51.3 /s
# Done  10.770 %, average grains/point   2.08, 0.006 /s/point, total 51.5 /s
# Done  10.817 %, average grains/point   2.08, 0.006 /s/point, total 51.6 /s
# Done  10.864 %, average grains/point   2.08, 0.006 /s/point, total 51.7 /s
# Done  10.912 %, average grains/point   2.09, 0.006 /s/point, total 51.8 /s
# Done  10.959 %, average grains/point   2.09, 0.006 /s/point, total 51.9 /s
# Done  11.006 %, average grains/point   2.09, 0.006 /s/point, total 52.1 /s
# Done  11.053 %, average grains/point   2.09, 0.006 /s/point, total 52.2 /s
# Done  11.100 %, average grains/point   2.09, 0.006 /s/point, total 52.3 /s
# Done  11.148 %, average grains/point   2.09, 0.006 /s/point, total 52.4 /s
# Done  11.195 %, average grains/point   2.09, 0.006 /s/point, total 52.6 /s
# Done  11.242 %, average grains/point   2.09, 0.006 /s/point, total 52.7 /s
# Done  11.289 %, average grains/point   2.09, 0.006 /s/point, total 52.8 /s
# Done  11.337 %, average grains/point   2.09, 0.006 /s/point, total 52.9 /s
# Done  11.384 %, average grains/point   2.09, 0.006 /s/point, total 53.1 /s
# Done  11.431 %, average grains/point   2.09, 0.005 /s/point, total 53.2 /s
# Done  11.478 %, average grains/point   2.09, 0.005 /s/point, total 53.3 /s
# Done  11.526 %, average grains/point   2.09, 0.005 /s/point, total 53.5 /s
# Done  11.573 %, average grains/point   2.09, 0.005 /s/point, total 53.6 /s
# Done  11.620 %, average grains/point   2.09, 0.005 /s/point, total 53.7 /s
# Done  11.667 %, average grains/point   2.09, 0.005 /s/point, total 53.9 /s
# Done  11.715 %, average grains/point   2.09, 0.005 /s/point, total 54.0 /s
# Done  11.762 %, average grains/point   2.09, 0.005 /s/point, total 54.1 /s
# Done  11.809 %, average grains/point   2.09, 0.005 /s/point, total 54.2 /s
# Done  11.856 %, average grains/point   2.09, 0.005 /s/point, total 54.3 /s
# Done  11.903 %, average grains/point   2.09, 0.005 /s/point, total 54.5 /s
# Done  11.951 %, average grains/point   2.09, 0.005 /s/point, total 54.6 /s
# Done  11.998 %, average grains/point   2.09, 0.005 /s/point, total 54.7 /s
# Done  12.045 %, average grains/point   2.09, 0.005 /s/point, total 54.9 /s
# Done  12.092 %, average grains/point   2.09, 0.005 /s/point, total 55.0 /s
# Done  12.140 %, average grains/point   2.09, 0.005 /s/point, total 55.1 /s
# Done  12.187 %, average grains/point   2.09, 0.005 /s/point, total 55.2 /s
# Done  12.234 %, average grains/point   2.09, 0.005 /s/point, total 55.4 /s
# Done  12.281 %, average grains/point   2.09, 0.005 /s/point, total 55.5 /s
# Done  12.329 %, average grains/point   2.09, 0.005 /s/point, total 55.6 /s
# Done  12.376 %, average grains/point   2.09, 0.005 /s/point, total 55.7 /s
# Done  12.423 %, average grains/point   2.09, 0.005 /s/point, total 55.9 /s
# Done  12.470 %, average grains/point   2.09, 0.005 /s/point, total 56.0 /s
# Done  12.518 %, average grains/point   2.09, 0.005 /s/point, total 56.1 /s
# Done  12.565 %, average grains/point   2.09, 0.005 /s/point, total 56.2 /s
# Done  12.612 %, average grains/point   2.09, 0.005 /s/point, total 56.4 /s
# Done  12.659 %, average grains/point   2.09, 0.005 /s/point, total 56.5 /s
# Done  12.707 %, average grains/point   2.09, 0.005 /s/point, total 56.6 /s
# Done  12.754 %, average grains/point   2.09, 0.005 /s/point, total 56.7 /s
# Done  12.801 %, average grains/point   2.09, 0.005 /s/point, total 56.9 /s
# Done  12.848 %, average grains/point   2.09, 0.005 /s/point, total 57.0 /s
# Done  12.895 %, average grains/point   2.09, 0.005 /s/point, total 57.1 /s
# Done  12.943 %, average grains/point   2.09, 0.005 /s/point, total 57.3 /s
# Done  12.990 %, average grains/point   2.09, 0.005 /s/point, total 57.4 /s
# Done  13.037 %, average grains/point   2.09, 0.005 /s/point, total 57.5 /s
# Done  13.084 %, average grains/point   2.09, 0.005 /s/point, total 57.6 /s
# Done  13.132 %, average grains/point   2.09, 0.005 /s/point, total 57.7 /s
# Done  13.179 %, average grains/point   2.09, 0.005 /s/point, total 57.8 /s
# Done  13.226 %, average grains/point   2.09, 0.005 /s/point, total 58.0 /s
# Done  13.273 %, average grains/point   2.09, 0.005 /s/point, total 58.1 /s
# Done  13.321 %, average grains/point   2.09, 0.005 /s/point, total 58.2 /s
# Done  13.368 %, average grains/point   2.09, 0.005 /s/point, total 58.3 /s
# Done  13.415 %, average grains/point   2.09, 0.005 /s/point, total 58.5 /s
# Done  13.462 %, average grains/point   2.09, 0.005 /s/point, total 58.6 /s
# Done  13.510 %, average grains/point   2.09, 0.005 /s/point, total 58.7 /s
# Done  13.557 %, average grains/point   2.10, 0.005 /s/point, total 58.9 /s
# Done  13.604 %, average grains/point   2.10, 0.005 /s/point, total 59.0 /s
# Done  13.651 %, average grains/point   2.09, 0.005 /s/point, total 59.1 /s
# Done  13.698 %, average grains/point   2.09, 0.005 /s/point, total 59.2 /s
# Done  13.746 %, average grains/point   2.09, 0.005 /s/point, total 59.4 /s
# Done  13.793 %, average grains/point   2.09, 0.005 /s/point, total 59.5 /s
# Done  13.840 %, average grains/point   2.09, 0.005 /s/point, total 59.6 /s
# Done  13.887 %, average grains/point   2.09, 0.005 /s/point, total 59.8 /s
# Done  13.935 %, average grains/point   2.09, 0.005 /s/point, total 59.9 /s
# Done  13.982 %, average grains/point   2.09, 0.005 /s/point, total 60.0 /s
# Done  14.029 %, average grains/point   2.09, 0.005 /s/point, total 60.1 /s
# Done  14.076 %, average grains/point   2.09, 0.005 /s/point, total 60.3 /s
# Done  14.124 %, average grains/point   2.09, 0.005 /s/point, total 60.4 /s
# Done  14.171 %, average grains/point   2.09, 0.005 /s/point, total 60.5 /s
# Done  14.218 %, average grains/point   2.09, 0.005 /s/point, total 60.6 /s
# Done  14.265 %, average grains/point   2.09, 0.005 /s/point, total 60.8 /s
# Done  14.313 %, average grains/point   2.09, 0.005 /s/point, total 60.9 /s
# Done  14.360 %, average grains/point   2.09, 0.005 /s/point, total 61.0 /s
# Done  14.407 %, average grains/point   2.09, 0.005 /s/point, total 61.1 /s
# Done  14.454 %, average grains/point   2.09, 0.005 /s/point, total 61.3 /s
# Done  14.501 %, average grains/point   2.09, 0.005 /s/point, total 61.4 /s
# Done  14.549 %, average grains/point   2.09, 0.005 /s/point, total 61.5 /s
# Done  14.596 %, average grains/point   2.09, 0.005 /s/point, total 61.6 /s
# Done  14.643 %, average grains/point   2.09, 0.005 /s/point, total 61.8 /s
# Done  14.690 %, average grains/point   2.09, 0.005 /s/point, total 61.9 /s
# Done  14.738 %, average grains/point   2.09, 0.005 /s/point, total 62.1 /s
# Done  14.785 %, average grains/point   2.09, 0.005 /s/point, total 62.2 /s
# Done  14.832 %, average grains/point   2.09, 0.005 /s/point, total 62.3 /s
# Done  14.879 %, average grains/point   2.09, 0.005 /s/point, total 62.4 /s
# Done  14.927 %, average grains/point   2.09, 0.005 /s/point, total 62.6 /s
# Done  14.974 %, average grains/point   2.09, 0.005 /s/point, total 62.7 /s
# Done  15.021 %, average grains/point   2.09, 0.005 /s/point, total 62.8 /s
# Done  15.068 %, average grains/point   2.09, 0.005 /s/point, total 62.9 /s
# Done  15.116 %, average grains/point   2.09, 0.005 /s/point, total 63.1 /s
# Done  15.163 %, average grains/point   2.09, 0.005 /s/point, total 63.2 /s
# Done  15.210 %, average grains/point   2.09, 0.005 /s/point, total 63.3 /s
# Done  15.257 %, average grains/point   2.09, 0.005 /s/point, total 63.4 /s
# Done  15.304 %, average grains/point   2.09, 0.005 /s/point, total 63.6 /s
# Done  15.352 %, average grains/point   2.09, 0.005 /s/point, total 63.7 /s
# Done  15.399 %, average grains/point   2.09, 0.005 /s/point, total 63.8 /s
# Done  15.446 %, average grains/point   2.09, 0.005 /s/point, total 63.9 /s
# Done  15.493 %, average grains/point   2.09, 0.005 /s/point, total 64.1 /s
# Done  15.541 %, average grains/point   2.09, 0.005 /s/point, total 64.2 /s
# Done  15.588 %, average grains/point   2.09, 0.005 /s/point, total 64.3 /s
# Done  15.635 %, average grains/point   2.09, 0.005 /s/point, total 64.4 /s
# Done  15.682 %, average grains/point   2.10, 0.005 /s/point, total 64.6 /s
# Done  15.730 %, average grains/point   2.09, 0.005 /s/point, total 64.7 /s
# Done  15.777 %, average grains/point   2.10, 0.005 /s/point, total 64.8 /s
# Done  15.824 %, average grains/point   2.10, 0.005 /s/point, total 64.9 /s
# Done  15.871 %, average grains/point   2.10, 0.005 /s/point, total 65.1 /s
# Done  15.919 %, average grains/point   2.10, 0.005 /s/point, total 65.2 /s
# Done  15.966 %, average grains/point   2.10, 0.005 /s/point, total 65.3 /s
# Done  16.013 %, average grains/point   2.10, 0.005 /s/point, total 65.5 /s
# Done  16.060 %, average grains/point   2.10, 0.005 /s/point, total 65.6 /s
# Done  16.108 %, average grains/point   2.10, 0.005 /s/point, total 65.7 /s
# Done  16.155 %, average grains/point   2.10, 0.005 /s/point, total 65.8 /s
# Done  16.202 %, average grains/point   2.10, 0.005 /s/point, total 66.0 /s
# Done  16.249 %, average grains/point   2.10, 0.005 /s/point, total 66.1 /s
# Done  16.296 %, average grains/point   2.10, 0.005 /s/point, total 66.2 /s
# Done  16.344 %, average grains/point   2.10, 0.005 /s/point, total 66.4 /s
# Done  16.391 %, average grains/point   2.10, 0.005 /s/point, total 66.5 /s
# Done  16.438 %, average grains/point   2.10, 0.005 /s/point, total 66.6 /s
# Done  16.485 %, average grains/point   2.10, 0.005 /s/point, total 66.7 /s
# Done  16.533 %, average grains/point   2.10, 0.005 /s/point, total 66.9 /s
# Done  16.580 %, average grains/point   2.10, 0.005 /s/point, total 67.0 /s
# Done  16.627 %, average grains/point   2.10, 0.005 /s/point, total 67.1 /s
# Done  16.674 %, average grains/point   2.10, 0.005 /s/point, total 67.3 /s
# Done  16.722 %, average grains/point   2.10, 0.005 /s/point, total 67.4 /s
# Done  16.769 %, average grains/point   2.10, 0.005 /s/point, total 67.5 /s
# Done  16.816 %, average grains/point   2.10, 0.005 /s/point, total 67.6 /s
# Done  16.863 %, average grains/point   2.10, 0.005 /s/point, total 67.7 /s
# Done  16.911 %, average grains/point   2.10, 0.005 /s/point, total 67.9 /s
# Done  16.958 %, average grains/point   2.10, 0.005 /s/point, total 68.0 /s
# Done  17.005 %, average grains/point   2.10, 0.005 /s/point, total 68.1 /s
# Done  17.052 %, average grains/point   2.10, 0.005 /s/point, total 68.2 /s
# Done  17.099 %, average grains/point   2.10, 0.005 /s/point, total 68.4 /s
# Done  17.147 %, average grains/point   2.10, 0.005 /s/point, total 68.5 /s
# Done  17.194 %, average grains/point   2.10, 0.005 /s/point, total 68.6 /s
# Done  17.241 %, average grains/point   2.10, 0.005 /s/point, total 68.7 /s
# Done  17.288 %, average grains/point   2.10, 0.005 /s/point, total 68.9 /s
# Done  17.336 %, average grains/point   2.10, 0.005 /s/point, total 69.0 /s
# Done  17.383 %, average grains/point   2.10, 0.005 /s/point, total 69.1 /s
# Done  17.430 %, average grains/point   2.10, 0.005 /s/point, total 69.3 /s
# Done  17.477 %, average grains/point   2.10, 0.005 /s/point, total 69.4 /s
# Done  17.525 %, average grains/point   2.10, 0.005 /s/point, total 69.5 /s
# Done  17.572 %, average grains/point   2.10, 0.005 /s/point, total 69.6 /s
# Done  17.619 %, average grains/point   2.10, 0.005 /s/point, total 69.8 /s
# Done  17.666 %, average grains/point   2.10, 0.005 /s/point, total 69.9 /s
# Done  17.714 %, average grains/point   2.10, 0.005 /s/point, total 70.0 /s
# Done  17.761 %, average grains/point   2.10, 0.005 /s/point, total 70.1 /s
# Done  17.808 %, average grains/point   2.10, 0.005 /s/point, total 70.3 /s
# Done  17.855 %, average grains/point   2.10, 0.005 /s/point, total 70.4 /s
# Done  17.902 %, average grains/point   2.10, 0.005 /s/point, total 70.5 /s
# Done  17.950 %, average grains/point   2.09, 0.005 /s/point, total 70.6 /s
# Done  17.997 %, average grains/point   2.10, 0.005 /s/point, total 70.8 /s
# Done  18.044 %, average grains/point   2.10, 0.005 /s/point, total 70.9 /s
# Done  18.091 %, average grains/point   2.09, 0.005 /s/point, total 71.0 /s
# Done  18.139 %, average grains/point   2.09, 0.005 /s/point, total 71.1 /s
# Done  18.186 %, average grains/point   2.09, 0.005 /s/point, total 71.3 /s
# Done  18.233 %, average grains/point   2.09, 0.005 /s/point, total 71.4 /s
# Done  18.280 %, average grains/point   2.09, 0.005 /s/point, total 71.5 /s
# Done  18.328 %, average grains/point   2.10, 0.005 /s/point, total 71.6 /s
# Done  18.375 %, average grains/point   2.10, 0.005 /s/point, total 71.8 /s
# Done  18.422 %, average grains/point   2.09, 0.005 /s/point, total 71.9 /s
# Done  18.469 %, average grains/point   2.10, 0.005 /s/point, total 72.0 /s
# Done  18.517 %, average grains/point   2.10, 0.005 /s/point, total 72.1 /s
# Done  18.564 %, average grains/point   2.10, 0.005 /s/point, total 72.3 /s
# Done  18.611 %, average grains/point   2.10, 0.005 /s/point, total 72.4 /s
# Done  18.658 %, average grains/point   2.09, 0.005 /s/point, total 72.5 /s
# Done  18.705 %, average grains/point   2.09, 0.005 /s/point, total 72.6 /s
# Done  18.753 %, average grains/point   2.09, 0.005 /s/point, total 72.8 /s
# Done  18.800 %, average grains/point   2.09, 0.005 /s/point, total 72.9 /s
# Done  18.847 %, average grains/point   2.09, 0.005 /s/point, total 73.1 /s
# Done  18.894 %, average grains/point   2.09, 0.005 /s/point, total 73.2 /s
# Done  18.942 %, average grains/point   2.09, 0.005 /s/point, total 73.3 /s
# Done  18.989 %, average grains/point   2.09, 0.005 /s/point, total 73.4 /s
# Done  19.036 %, average grains/point   2.09, 0.005 /s/point, total 73.5 /s
# Done  19.083 %, average grains/point   2.09, 0.005 /s/point, total 73.7 /s
# Done  19.131 %, average grains/point   2.09, 0.005 /s/point, total 73.8 /s
# Done  19.178 %, average grains/point   2.09, 0.005 /s/point, total 73.9 /s
# Done  19.225 %, average grains/point   2.09, 0.005 /s/point, total 74.0 /s
# Done  19.272 %, average grains/point   2.09, 0.005 /s/point, total 74.2 /s
# Done  19.320 %, average grains/point   2.09, 0.005 /s/point, total 74.3 /s
# Done  19.367 %, average grains/point   2.09, 0.005 /s/point, total 74.4 /s
# Done  19.414 %, average grains/point   2.09, 0.005 /s/point, total 74.6 /s
# Done  19.461 %, average grains/point   2.09, 0.005 /s/point, total 74.7 /s
# Done  19.509 %, average grains/point   2.09, 0.005 /s/point, total 74.8 /s
# Done  19.556 %, average grains/point   2.09, 0.005 /s/point, total 75.0 /s
# Done  19.603 %, average grains/point   2.09, 0.005 /s/point, total 75.1 /s
# Done  19.650 %, average grains/point   2.09, 0.005 /s/point, total 75.2 /s
# Done  19.697 %, average grains/point   2.09, 0.005 /s/point, total 75.3 /s
# Done  19.745 %, average grains/point   2.09, 0.005 /s/point, total 75.4 /s
# Done  19.792 %, average grains/point   2.09, 0.005 /s/point, total 75.5 /s
# Done  19.839 %, average grains/point   2.09, 0.005 /s/point, total 75.7 /s
# Done  19.886 %, average grains/point   2.09, 0.005 /s/point, total 75.8 /s
# Done  19.934 %, average grains/point   2.09, 0.004 /s/point, total 76.0 /s
# Done  19.981 %, average grains/point   2.09, 0.004 /s/point, total 76.1 /s
# Done  20.028 %, average grains/point   2.09, 0.004 /s/point, total 76.2 /s
# Done  20.075 %, average grains/point   2.09, 0.004 /s/point, total 76.3 /s
# Done  20.123 %, average grains/point   2.09, 0.004 /s/point, total 76.5 /s
# Done  20.170 %, average grains/point   2.10, 0.004 /s/point, total 76.6 /s
# Done  20.217 %, average grains/point   2.10, 0.004 /s/point, total 76.7 /s
# Done  20.264 %, average grains/point   2.10, 0.004 /s/point, total 76.8 /s
# Done  20.312 %, average grains/point   2.09, 0.004 /s/point, total 77.0 /s
# Done  20.359 %, average grains/point   2.09, 0.004 /s/point, total 77.1 /s
# Done  20.406 %, average grains/point   2.09, 0.004 /s/point, total 77.2 /s
# Done  20.453 %, average grains/point   2.09, 0.004 /s/point, total 77.3 /s
# Done  20.500 %, average grains/point   2.09, 0.004 /s/point, total 77.5 /s
# Done  20.548 %, average grains/point   2.09, 0.004 /s/point, total 77.6 /s
# Done  20.595 %, average grains/point   2.09, 0.004 /s/point, total 77.7 /s
# Done  20.642 %, average grains/point   2.09, 0.004 /s/point, total 77.9 /s
# Done  20.689 %, average grains/point   2.09, 0.004 /s/point, total 78.0 /s
# Done  20.737 %, average grains/point   2.09, 0.004 /s/point, total 78.1 /s
# Done  20.784 %, average grains/point   2.09, 0.004 /s/point, total 78.3 /s
# Done  20.831 %, average grains/point   2.09, 0.004 /s/point, total 78.4 /s
# Done  20.878 %, average grains/point   2.09, 0.004 /s/point, total 78.5 /s
# Done  20.926 %, average grains/point   2.09, 0.004 /s/point, total 78.6 /s
# Done  20.973 %, average grains/point   2.09, 0.004 /s/point, total 78.8 /s
# Done  21.020 %, average grains/point   2.09, 0.004 /s/point, total 78.9 /s
# Done  21.067 %, average grains/point   2.09, 0.004 /s/point, total 79.0 /s
# Done  21.115 %, average grains/point   2.09, 0.004 /s/point, total 79.1 /s
# Done  21.162 %, average grains/point   2.09, 0.004 /s/point, total 79.3 /s
# Done  21.209 %, average grains/point   2.09, 0.004 /s/point, total 79.4 /s
# Done  21.256 %, average grains/point   2.10, 0.004 /s/point, total 79.5 /s
# Done  21.303 %, average grains/point   2.09, 0.004 /s/point, total 79.6 /s
# Done  21.351 %, average grains/point   2.10, 0.004 /s/point, total 79.8 /s
# Done  21.398 %, average grains/point   2.10, 0.004 /s/point, total 79.9 /s
# Done  21.445 %, average grains/point   2.10, 0.004 /s/point, total 80.0 /s
# Done  21.492 %, average grains/point   2.10, 0.004 /s/point, total 80.1 /s
# Done  21.540 %, average grains/point   2.10, 0.004 /s/point, total 80.3 /s
# Done  21.587 %, average grains/point   2.09, 0.004 /s/point, total 80.4 /s
# Done  21.634 %, average grains/point   2.09, 0.004 /s/point, total 80.5 /s
# Done  21.681 %, average grains/point   2.09, 0.004 /s/point, total 80.7 /s
# Done  21.729 %, average grains/point   2.09, 0.004 /s/point, total 80.8 /s
# Done  21.776 %, average grains/point   2.09, 0.004 /s/point, total 80.9 /s
# Done  21.823 %, average grains/point   2.09, 0.004 /s/point, total 81.0 /s
# Done  21.870 %, average grains/point   2.09, 0.004 /s/point, total 81.2 /s
# Done  21.918 %, average grains/point   2.09, 0.004 /s/point, total 81.3 /s
# Done  21.965 %, average grains/point   2.09, 0.004 /s/point, total 81.4 /s
# Done  22.012 %, average grains/point   2.09, 0.004 /s/point, total 81.5 /s
# Done  22.059 %, average grains/point   2.09, 0.004 /s/point, total 81.7 /s
# Done  22.106 %, average grains/point   2.09, 0.004 /s/point, total 81.8 /s
# Done  22.154 %, average grains/point   2.09, 0.004 /s/point, total 81.9 /s
# Done  22.201 %, average grains/point   2.09, 0.004 /s/point, total 82.1 /s
# Done  22.248 %, average grains/point   2.09, 0.004 /s/point, total 82.2 /s
# Done  22.295 %, average grains/point   2.09, 0.004 /s/point, total 82.3 /s
# Done  22.343 %, average grains/point   2.09, 0.004 /s/point, total 82.4 /s
# Done  22.390 %, average grains/point   2.10, 0.004 /s/point, total 82.6 /s
# Done  22.437 %, average grains/point   2.10, 0.004 /s/point, total 82.7 /s
# Done  22.484 %, average grains/point   2.10, 0.004 /s/point, total 82.8 /s
# Done  22.532 %, average grains/point   2.09, 0.004 /s/point, total 83.0 /s
# Done  22.579 %, average grains/point   2.09, 0.004 /s/point, total 83.1 /s
# Done  22.626 %, average grains/point   2.09, 0.004 /s/point, total 83.2 /s
# Done  22.673 %, average grains/point   2.09, 0.004 /s/point, total 83.3 /s
# Done  22.721 %, average grains/point   2.09, 0.004 /s/point, total 83.5 /s
# Done  22.768 %, average grains/point   2.10, 0.004 /s/point, total 83.6 /s
# Done  22.815 %, average grains/point   2.10, 0.004 /s/point, total 83.7 /s
# Done  22.862 %, average grains/point   2.10, 0.004 /s/point, total 83.9 /s
# Done  22.910 %, average grains/point   2.10, 0.004 /s/point, total 84.0 /s
# Done  22.957 %, average grains/point   2.10, 0.004 /s/point, total 84.1 /s
# Done  23.004 %, average grains/point   2.10, 0.004 /s/point, total 84.2 /s
# Done  23.051 %, average grains/point   2.10, 0.004 /s/point, total 84.3 /s
# Done  23.098 %, average grains/point   2.10, 0.004 /s/point, total 84.5 /s
# Done  23.146 %, average grains/point   2.10, 0.004 /s/point, total 84.6 /s
# Done  23.193 %, average grains/point   2.10, 0.004 /s/point, total 84.7 /s
# Done  23.240 %, average grains/point   2.10, 0.004 /s/point, total 84.8 /s
# Done  23.287 %, average grains/point   2.09, 0.004 /s/point, total 85.0 /s
# Done  23.335 %, average grains/point   2.09, 0.004 /s/point, total 85.1 /s
# Done  23.382 %, average grains/point   2.09, 0.004 /s/point, total 85.2 /s
# Done  23.429 %, average grains/point   2.10, 0.004 /s/point, total 85.3 /s
# Done  23.476 %, average grains/point   2.10, 0.004 /s/point, total 85.5 /s
# Done  23.524 %, average grains/point   2.10, 0.004 /s/point, total 85.6 /s
# Done  23.571 %, average grains/point   2.10, 0.004 /s/point, total 85.7 /s
# Done  23.618 %, average grains/point   2.10, 0.004 /s/point, total 85.8 /s
# Done  23.665 %, average grains/point   2.10, 0.004 /s/point, total 86.0 /s
# Done  23.713 %, average grains/point   2.10, 0.004 /s/point, total 86.1 /s
# Done  23.760 %, average grains/point   2.10, 0.004 /s/point, total 86.2 /s
# Done  23.807 %, average grains/point   2.10, 0.004 /s/point, total 86.4 /s
# Done  23.854 %, average grains/point   2.10, 0.004 /s/point, total 86.5 /s
# Done  23.901 %, average grains/point   2.10, 0.004 /s/point, total 86.6 /s
# Done  23.949 %, average grains/point   2.10, 0.004 /s/point, total 86.7 /s
# Done  23.996 %, average grains/point   2.10, 0.004 /s/point, total 86.9 /s
# Done  24.043 %, average grains/point   2.10, 0.004 /s/point, total 87.0 /s
# Done  24.090 %, average grains/point   2.10, 0.004 /s/point, total 87.1 /s
# Done  24.138 %, average grains/point   2.10, 0.004 /s/point, total 87.2 /s
# Done  24.185 %, average grains/point   2.10, 0.004 /s/point, total 87.4 /s
# Done  24.232 %, average grains/point   2.10, 0.004 /s/point, total 87.5 /s
# Done  24.279 %, average grains/point   2.10, 0.004 /s/point, total 87.6 /s
# Done  24.327 %, average grains/point   2.10, 0.004 /s/point, total 87.8 /s
# Done  24.374 %, average grains/point   2.10, 0.004 /s/point, total 87.9 /s
# Done  24.421 %, average grains/point   2.10, 0.004 /s/point, total 88.0 /s
# Done  24.468 %, average grains/point   2.10, 0.004 /s/point, total 88.1 /s
# Done  24.516 %, average grains/point   2.10, 0.004 /s/point, total 88.3 /s
# Done  24.563 %, average grains/point   2.10, 0.004 /s/point, total 88.4 /s
# Done  24.610 %, average grains/point   2.10, 0.004 /s/point, total 88.5 /s
# Done  24.657 %, average grains/point   2.10, 0.004 /s/point, total 88.6 /s
# Done  24.704 %, average grains/point   2.10, 0.004 /s/point, total 88.7 /s
# Done  24.752 %, average grains/point   2.10, 0.004 /s/point, total 88.9 /s
# Done  24.799 %, average grains/point   2.10, 0.004 /s/point, total 89.0 /s
# Done  24.846 %, average grains/point   2.10, 0.004 /s/point, total 89.1 /s
# Done  24.893 %, average grains/point   2.10, 0.004 /s/point, total 89.3 /s
# Done  24.941 %, average grains/point   2.10, 0.004 /s/point, total 89.4 /s
# Done  24.988 %, average grains/point   2.10, 0.004 /s/point, total 89.5 /s
# Done  25.035 %, average grains/point   2.10, 0.004 /s/point, total 89.6 /s
# Done  25.082 %, average grains/point   2.10, 0.004 /s/point, total 89.8 /s
# Done  25.130 %, average grains/point   2.10, 0.004 /s/point, total 89.9 /s
# Done  25.177 %, average grains/point   2.10, 0.004 /s/point, total 90.0 /s
# Done  25.224 %, average grains/point   2.10, 0.004 /s/point, total 90.1 /s
# Done  25.271 %, average grains/point   2.10, 0.004 /s/point, total 90.3 /s
# Done  25.319 %, average grains/point   2.10, 0.004 /s/point, total 90.4 /s
# Done  25.366 %, average grains/point   2.10, 0.004 /s/point, total 90.5 /s
# Done  25.413 %, average grains/point   2.10, 0.004 /s/point, total 90.6 /s
# Done  25.460 %, average grains/point   2.10, 0.004 /s/point, total 90.8 /s
# Done  25.507 %, average grains/point   2.10, 0.004 /s/point, total 90.9 /s
# Done  25.555 %, average grains/point   2.10, 0.004 /s/point, total 91.0 /s
# Done  25.602 %, average grains/point   2.10, 0.004 /s/point, total 91.1 /s
# Done  25.649 %, average grains/point   2.10, 0.004 /s/point, total 91.3 /s
# Done  25.696 %, average grains/point   2.10, 0.004 /s/point, total 91.4 /s
# Done  25.744 %, average grains/point   2.10, 0.004 /s/point, total 91.5 /s
# Done  25.791 %, average grains/point   2.10, 0.004 /s/point, total 91.6 /s
# Done  25.838 %, average grains/point   2.10, 0.004 /s/point, total 91.8 /s
# Done  25.885 %, average grains/point   2.10, 0.004 /s/point, total 91.9 /s
# Done  25.933 %, average grains/point   2.10, 0.004 /s/point, total 92.0 /s
# Done  25.980 %, average grains/point   2.10, 0.004 /s/point, total 92.2 /s
# Done  26.027 %, average grains/point   2.10, 0.004 /s/point, total 92.3 /s
# Done  26.074 %, average grains/point   2.10, 0.004 /s/point, total 92.4 /s
# Done  26.122 %, average grains/point   2.10, 0.004 /s/point, total 92.5 /s
# Done  26.169 %, average grains/point   2.10, 0.004 /s/point, total 92.6 /s
# Done  26.216 %, average grains/point   2.09, 0.004 /s/point, total 92.8 /s
# Done  26.263 %, average grains/point   2.10, 0.004 /s/point, total 92.9 /s
# Done  26.311 %, average grains/point   2.10, 0.004 /s/point, total 93.0 /s
# Done  26.358 %, average grains/point   2.10, 0.004 /s/point, total 93.2 /s
# Done  26.405 %, average grains/point   2.10, 0.004 /s/point, total 93.3 /s
# Done  26.452 %, average grains/point   2.10, 0.004 /s/point, total 93.4 /s
# Done  26.499 %, average grains/point   2.10, 0.004 /s/point, total 93.5 /s
# Done  26.547 %, average grains/point   2.10, 0.004 /s/point, total 93.7 /s
# Done  26.594 %, average grains/point   2.10, 0.004 /s/point, total 93.8 /s
# Done  26.641 %, average grains/point   2.10, 0.004 /s/point, total 93.9 /s
# Done  26.688 %, average grains/point   2.10, 0.004 /s/point, total 94.0 /s
# Done  26.736 %, average grains/point   2.10, 0.004 /s/point, total 94.2 /s
# Done  26.783 %, average grains/point   2.10, 0.004 /s/point, total 94.3 /s
# Done  26.830 %, average grains/point   2.10, 0.004 /s/point, total 94.4 /s
# Done  26.877 %, average grains/point   2.10, 0.004 /s/point, total 94.5 /s
# Done  26.925 %, average grains/point   2.10, 0.004 /s/point, total 94.7 /s
# Done  26.972 %, average grains/point   2.10, 0.004 /s/point, total 94.8 /s
# Done  27.019 %, average grains/point   2.10, 0.004 /s/point, total 94.9 /s
# Done  27.066 %, average grains/point   2.10, 0.004 /s/point, total 95.0 /s
# Done  27.114 %, average grains/point   2.10, 0.004 /s/point, total 95.2 /s
# Done  27.161 %, average grains/point   2.10, 0.004 /s/point, total 95.3 /s
# Done  27.208 %, average grains/point   2.10, 0.004 /s/point, total 95.4 /s
# Done  27.255 %, average grains/point   2.10, 0.004 /s/point, total 95.5 /s
# Done  27.302 %, average grains/point   2.10, 0.004 /s/point, total 95.7 /s
# Done  27.350 %, average grains/point   2.10, 0.004 /s/point, total 95.8 /s
# Done  27.397 %, average grains/point   2.10, 0.004 /s/point, total 95.9 /s
# Done  27.444 %, average grains/point   2.10, 0.004 /s/point, total 96.0 /s
# Done  27.491 %, average grains/point   2.10, 0.004 /s/point, total 96.2 /s
# Done  27.539 %, average grains/point   2.10, 0.004 /s/point, total 96.3 /s
# Done  27.586 %, average grains/point   2.10, 0.004 /s/point, total 96.4 /s
# Done  27.633 %, average grains/point   2.10, 0.004 /s/point, total 96.5 /s
# Done  27.680 %, average grains/point   2.10, 0.004 /s/point, total 96.7 /s
# Done  27.728 %, average grains/point   2.10, 0.004 /s/point, total 96.8 /s
# Done  27.775 %, average grains/point   2.10, 0.004 /s/point, total 97.0 /s
# Done  27.822 %, average grains/point   2.10, 0.004 /s/point, total 97.1 /s
# Done  27.869 %, average grains/point   2.10, 0.004 /s/point, total 97.2 /s
# Done  27.917 %, average grains/point   2.10, 0.004 /s/point, total 97.3 /s
# Done  27.964 %, average grains/point   2.10, 0.004 /s/point, total 97.4 /s
# Done  28.011 %, average grains/point   2.10, 0.004 /s/point, total 97.5 /s
# Done  28.058 %, average grains/point   2.10, 0.004 /s/point, total 97.7 /s
# Done  28.105 %, average grains/point   2.10, 0.004 /s/point, total 97.8 /s
# Done  28.153 %, average grains/point   2.10, 0.004 /s/point, total 97.9 /s
# Done  28.200 %, average grains/point   2.10, 0.004 /s/point, total 98.1 /s
# Done  28.247 %, average grains/point   2.10, 0.004 /s/point, total 98.2 /s
# Done  28.294 %, average grains/point   2.10, 0.004 /s/point, total 98.3 /s
# Done  28.342 %, average grains/point   2.10, 0.004 /s/point, total 98.5 /s
# Done  28.389 %, average grains/point   2.10, 0.004 /s/point, total 98.6 /s
# Done  28.436 %, average grains/point   2.10, 0.004 /s/point, total 98.7 /s
# Done  28.483 %, average grains/point   2.10, 0.004 /s/point, total 98.8 /s
# Done  28.531 %, average grains/point   2.10, 0.004 /s/point, total 99.0 /s
# Done  28.578 %, average grains/point   2.10, 0.004 /s/point, total 99.1 /s
# Done  28.625 %, average grains/point   2.10, 0.004 /s/point, total 99.2 /s
# Done  28.672 %, average grains/point   2.10, 0.004 /s/point, total 99.3 /s
# Done  28.720 %, average grains/point   2.10, 0.004 /s/point, total 99.5 /s
# Done  28.767 %, average grains/point   2.10, 0.004 /s/point, total 99.6 /s
# Done  28.814 %, average grains/point   2.10, 0.004 /s/point, total 99.8 /s
# Done  28.861 %, average grains/point   2.10, 0.004 /s/point, total 99.9 /s
# Done  28.908 %, average grains/point   2.10, 0.004 /s/point, total 100.0 /s
# Done  28.956 %, average grains/point   2.10, 0.004 /s/point, total 100.1 /s
# Done  29.003 %, average grains/point   2.10, 0.004 /s/point, total 100.2 /s
# Done  29.050 %, average grains/point   2.10, 0.004 /s/point, total 100.4 /s
# Done  29.097 %, average grains/point   2.10, 0.004 /s/point, total 100.5 /s
# Done  29.145 %, average grains/point   2.10, 0.004 /s/point, total 100.6 /s
# Done  29.192 %, average grains/point   2.10, 0.004 /s/point, total 100.7 /s
# Done  29.239 %, average grains/point   2.10, 0.004 /s/point, total 100.9 /s
# Done  29.286 %, average grains/point   2.10, 0.004 /s/point, total 101.0 /s
# Done  29.334 %, average grains/point   2.10, 0.004 /s/point, total 101.1 /s
# Done  29.381 %, average grains/point   2.10, 0.004 /s/point, total 101.3 /s
# Done  29.428 %, average grains/point   2.09, 0.004 /s/point, total 101.4 /s
# Done  29.475 %, average grains/point   2.09, 0.004 /s/point, total 101.5 /s
# Done  29.523 %, average grains/point   2.10, 0.004 /s/point, total 101.6 /s
# Done  29.570 %, average grains/point   2.10, 0.004 /s/point, total 101.8 /s
# Done  29.617 %, average grains/point   2.10, 0.004 /s/point, total 101.9 /s
# Done  29.664 %, average grains/point   2.09, 0.004 /s/point, total 102.0 /s
# Done  29.712 %, average grains/point   2.10, 0.004 /s/point, total 102.1 /s
# Done  29.759 %, average grains/point   2.10, 0.004 /s/point, total 102.3 /s
# Done  29.806 %, average grains/point   2.10, 0.004 /s/point, total 102.4 /s
# Done  29.853 %, average grains/point   2.09, 0.004 /s/point, total 102.5 /s
# Done  29.900 %, average grains/point   2.09, 0.004 /s/point, total 102.7 /s
# Done  29.948 %, average grains/point   2.09, 0.004 /s/point, total 102.8 /s
# Done  29.995 %, average grains/point   2.09, 0.004 /s/point, total 102.9 /s
# Done  30.042 %, average grains/point   2.09, 0.004 /s/point, total 103.0 /s
# ...
# Done  90.221 %, average grains/point   2.10, 0.003 /s/point, total 264.6 /s
# Done  90.268 %, average grains/point   2.10, 0.003 /s/point, total 264.8 /s
# Done  90.315 %, average grains/point   2.10, 0.003 /s/point, total 264.9 /s
# Done  90.363 %, average grains/point   2.10, 0.003 /s/point, total 265.0 /s
# Done  90.410 %, average grains/point   2.10, 0.003 /s/point, total 265.2 /s
# Done  90.457 %, average grains/point   2.10, 0.003 /s/point, total 265.3 /s
# Done  90.504 %, average grains/point   2.10, 0.003 /s/point, total 265.4 /s
# Done  90.552 %, average grains/point   2.10, 0.003 /s/point, total 265.5 /s
# Done  90.599 %, average grains/point   2.10, 0.003 /s/point, total 265.6 /s
# Done  90.646 %, average grains/point   2.10, 0.003 /s/point, total 265.8 /s
# Done  90.693 %, average grains/point   2.10, 0.003 /s/point, total 265.9 /s
# Done  90.741 %, average grains/point   2.10, 0.003 /s/point, total 266.0 /s
# Done  90.788 %, average grains/point   2.10, 0.003 /s/point, total 266.1 /s
# Done  90.835 %, average grains/point   2.10, 0.003 /s/point, total 266.3 /s
# Done  90.882 %, average grains/point   2.10, 0.003 /s/point, total 266.4 /s
# Done  90.929 %, average grains/point   2.10, 0.003 /s/point, total 266.5 /s
# Done  90.977 %, average grains/point   2.10, 0.003 /s/point, total 266.7 /s
# Done  91.024 %, average grains/point   2.10, 0.003 /s/point, total 266.8 /s
# Done  91.071 %, average grains/point   2.10, 0.003 /s/point, total 266.9 /s
# Done  91.118 %, average grains/point   2.10, 0.003 /s/point, total 267.0 /s
# Done  91.166 %, average grains/point   2.10, 0.003 /s/point, total 267.2 /s
# Done  91.213 %, average grains/point   2.10, 0.003 /s/point, total 267.3 /s
# Done  91.260 %, average grains/point   2.10, 0.003 /s/point, total 267.4 /s
# Done  91.307 %, average grains/point   2.10, 0.003 /s/point, total 267.5 /s
# Done  91.355 %, average grains/point   2.10, 0.003 /s/point, total 267.7 /s
# Done  91.402 %, average grains/point   2.10, 0.003 /s/point, total 267.8 /s
# Done  91.449 %, average grains/point   2.10, 0.003 /s/point, total 267.9 /s
# Done  91.496 %, average grains/point   2.10, 0.003 /s/point, total 268.1 /s
# Done  91.544 %, average grains/point   2.10, 0.003 /s/point, total 268.2 /s
# Done  91.591 %, average grains/point   2.10, 0.003 /s/point, total 268.3 /s
# Done  91.638 %, average grains/point   2.10, 0.003 /s/point, total 268.4 /s
# Done  91.685 %, average grains/point   2.10, 0.003 /s/point, total 268.6 /s
# Done  91.733 %, average grains/point   2.10, 0.003 /s/point, total 268.7 /s
# Done  91.780 %, average grains/point   2.10, 0.003 /s/point, total 268.8 /s
# Done  91.827 %, average grains/point   2.10, 0.003 /s/point, total 268.9 /s
# Done  91.874 %, average grains/point   2.10, 0.003 /s/point, total 269.1 /s
# Done  91.921 %, average grains/point   2.10, 0.003 /s/point, total 269.2 /s
# Done  91.969 %, average grains/point   2.10, 0.003 /s/point, total 269.3 /s
# Done  92.016 %, average grains/point   2.10, 0.003 /s/point, total 269.4 /s
# Done  92.063 %, average grains/point   2.09, 0.003 /s/point, total 269.6 /s
# Done  92.110 %, average grains/point   2.10, 0.003 /s/point, total 269.7 /s
# Done  92.158 %, average grains/point   2.09, 0.003 /s/point, total 269.8 /s
# Done  92.205 %, average grains/point   2.09, 0.003 /s/point, total 269.9 /s
# Done  92.252 %, average grains/point   2.09, 0.003 /s/point, total 270.1 /s
# Done  92.299 %, average grains/point   2.10, 0.003 /s/point, total 270.2 /s
# Done  92.347 %, average grains/point   2.10, 0.003 /s/point, total 270.3 /s
# Done  92.394 %, average grains/point   2.10, 0.003 /s/point, total 270.4 /s
# Done  92.441 %, average grains/point   2.10, 0.003 /s/point, total 270.6 /s
# Done  92.488 %, average grains/point   2.10, 0.003 /s/point, total 270.7 /s
# Done  92.536 %, average grains/point   2.10, 0.003 /s/point, total 270.8 /s
# Done  92.583 %, average grains/point   2.10, 0.003 /s/point, total 270.9 /s
# Done  92.630 %, average grains/point   2.10, 0.003 /s/point, total 271.1 /s
# Done  92.677 %, average grains/point   2.10, 0.003 /s/point, total 271.2 /s
# Done  92.724 %, average grains/point   2.10, 0.003 /s/point, total 271.3 /s
# Done  92.772 %, average grains/point   2.10, 0.003 /s/point, total 271.5 /s
# Done  92.819 %, average grains/point   2.09, 0.003 /s/point, total 271.6 /s
# Done  92.866 %, average grains/point   2.10, 0.003 /s/point, total 271.7 /s
# Done  92.913 %, average grains/point   2.10, 0.003 /s/point, total 271.8 /s
# Done  92.961 %, average grains/point   2.09, 0.003 /s/point, total 272.0 /s
# Done  93.008 %, average grains/point   2.09, 0.003 /s/point, total 272.1 /s
# Done  93.055 %, average grains/point   2.10, 0.003 /s/point, total 272.2 /s
# Done  93.102 %, average grains/point   2.09, 0.003 /s/point, total 272.4 /s
# Done  93.150 %, average grains/point   2.09, 0.003 /s/point, total 272.5 /s
# Done  93.197 %, average grains/point   2.09, 0.003 /s/point, total 272.6 /s
# Done  93.244 %, average grains/point   2.09, 0.003 /s/point, total 272.7 /s
# Done  93.291 %, average grains/point   2.09, 0.003 /s/point, total 272.8 /s
# Done  93.339 %, average grains/point   2.10, 0.003 /s/point, total 273.0 /s
# Done  93.386 %, average grains/point   2.10, 0.003 /s/point, total 273.1 /s
# Done  93.433 %, average grains/point   2.10, 0.003 /s/point, total 273.2 /s
# Done  93.480 %, average grains/point   2.10, 0.003 /s/point, total 273.3 /s
# Done  93.527 %, average grains/point   2.10, 0.003 /s/point, total 273.4 /s
# Done  93.575 %, average grains/point   2.10, 0.003 /s/point, total 273.6 /s
# Done  93.622 %, average grains/point   2.10, 0.003 /s/point, total 273.7 /s
# Done  93.669 %, average grains/point   2.10, 0.003 /s/point, total 273.8 /s
# Done  93.716 %, average grains/point   2.10, 0.003 /s/point, total 274.0 /s
# Done  93.764 %, average grains/point   2.10, 0.003 /s/point, total 274.1 /s
# Done  93.811 %, average grains/point   2.10, 0.003 /s/point, total 274.2 /s
# Done  93.858 %, average grains/point   2.10, 0.003 /s/point, total 274.3 /s
# Done  93.905 %, average grains/point   2.10, 0.003 /s/point, total 274.5 /s
# Done  93.953 %, average grains/point   2.09, 0.003 /s/point, total 274.6 /s
# Done  94.000 %, average grains/point   2.10, 0.003 /s/point, total 274.7 /s
# Done  94.047 %, average grains/point   2.10, 0.003 /s/point, total 274.8 /s
# Done  94.094 %, average grains/point   2.10, 0.003 /s/point, total 274.9 /s
# Done  94.142 %, average grains/point   2.09, 0.003 /s/point, total 275.1 /s
# Done  94.189 %, average grains/point   2.09, 0.003 /s/point, total 275.2 /s
# Done  94.236 %, average grains/point   2.09, 0.003 /s/point, total 275.4 /s
# Done  94.283 %, average grains/point   2.09, 0.003 /s/point, total 275.5 /s
# Done  94.330 %, average grains/point   2.09, 0.003 /s/point, total 275.6 /s
# Done  94.378 %, average grains/point   2.09, 0.003 /s/point, total 275.7 /s
# Done  94.425 %, average grains/point   2.10, 0.003 /s/point, total 275.9 /s
# Done  94.472 %, average grains/point   2.10, 0.003 /s/point, total 276.0 /s
# Done  94.519 %, average grains/point   2.10, 0.003 /s/point, total 276.1 /s
# Done  94.567 %, average grains/point   2.10, 0.003 /s/point, total 276.3 /s
# Done  94.614 %, average grains/point   2.09, 0.003 /s/point, total 276.4 /s
# Done  94.661 %, average grains/point   2.09, 0.003 /s/point, total 276.5 /s
# Done  94.708 %, average grains/point   2.09, 0.003 /s/point, total 276.6 /s
# Done  94.756 %, average grains/point   2.09, 0.003 /s/point, total 276.8 /s
# Done  94.803 %, average grains/point   2.09, 0.003 /s/point, total 276.9 /s
# Done  94.850 %, average grains/point   2.09, 0.003 /s/point, total 277.0 /s
# Done  94.897 %, average grains/point   2.09, 0.003 /s/point, total 277.1 /s
# Done  94.945 %, average grains/point   2.09, 0.003 /s/point, total 277.3 /s
# Done  94.992 %, average grains/point   2.09, 0.003 /s/point, total 277.4 /s
# Done  95.039 %, average grains/point   2.09, 0.003 /s/point, total 277.5 /s
# Done  95.086 %, average grains/point   2.09, 0.003 /s/point, total 277.6 /s
# Done  95.134 %, average grains/point   2.09, 0.003 /s/point, total 277.7 /s
# Done  95.181 %, average grains/point   2.09, 0.003 /s/point, total 277.9 /s
# Done  95.228 %, average grains/point   2.09, 0.003 /s/point, total 278.0 /s
# Done  95.275 %, average grains/point   2.09, 0.003 /s/point, total 278.1 /s
# Done  95.322 %, average grains/point   2.09, 0.003 /s/point, total 278.3 /s
# Done  95.370 %, average grains/point   2.09, 0.003 /s/point, total 278.4 /s
# Done  95.417 %, average grains/point   2.09, 0.003 /s/point, total 278.5 /s
# Done  95.464 %, average grains/point   2.09, 0.003 /s/point, total 278.6 /s
# Done  95.511 %, average grains/point   2.09, 0.003 /s/point, total 278.8 /s
# Done  95.559 %, average grains/point   2.09, 0.003 /s/point, total 278.9 /s
# Done  95.606 %, average grains/point   2.09, 0.003 /s/point, total 279.0 /s
# Done  95.653 %, average grains/point   2.09, 0.003 /s/point, total 279.1 /s
# Done  95.700 %, average grains/point   2.09, 0.003 /s/point, total 279.3 /s
# Done  95.748 %, average grains/point   2.09, 0.003 /s/point, total 279.4 /s
# Done  95.795 %, average grains/point   2.09, 0.003 /s/point, total 279.5 /s
# Done  95.842 %, average grains/point   2.09, 0.003 /s/point, total 279.6 /s
# Done  95.889 %, average grains/point   2.09, 0.003 /s/point, total 279.8 /s
# Done  95.937 %, average grains/point   2.09, 0.003 /s/point, total 279.9 /s
# Done  95.984 %, average grains/point   2.09, 0.003 /s/point, total 280.0 /s
# Done  96.031 %, average grains/point   2.09, 0.003 /s/point, total 280.1 /s
# Done  96.078 %, average grains/point   2.10, 0.003 /s/point, total 280.3 /s
# Done  96.125 %, average grains/point   2.10, 0.003 /s/point, total 280.4 /s
# Done  96.173 %, average grains/point   2.10, 0.003 /s/point, total 280.5 /s
# Done  96.220 %, average grains/point   2.10, 0.003 /s/point, total 280.6 /s
# Done  96.267 %, average grains/point   2.10, 0.003 /s/point, total 280.8 /s
# Done  96.314 %, average grains/point   2.10, 0.003 /s/point, total 280.9 /s
# Done  96.362 %, average grains/point   2.10, 0.003 /s/point, total 281.0 /s
# Done  96.409 %, average grains/point   2.10, 0.003 /s/point, total 281.1 /s
# Done  96.456 %, average grains/point   2.09, 0.003 /s/point, total 281.3 /s
# Done  96.503 %, average grains/point   2.09, 0.003 /s/point, total 281.4 /s
# Done  96.551 %, average grains/point   2.09, 0.003 /s/point, total 281.5 /s
# Done  96.598 %, average grains/point   2.09, 0.003 /s/point, total 281.7 /s
# Done  96.645 %, average grains/point   2.09, 0.003 /s/point, total 281.8 /s
# Done  96.692 %, average grains/point   2.09, 0.003 /s/point, total 281.9 /s
# Done  96.740 %, average grains/point   2.09, 0.003 /s/point, total 282.0 /s
# Done  96.787 %, average grains/point   2.09, 0.003 /s/point, total 282.2 /s
# Done  96.834 %, average grains/point   2.09, 0.003 /s/point, total 282.3 /s
# Done  96.881 %, average grains/point   2.09, 0.003 /s/point, total 282.4 /s
# Done  96.928 %, average grains/point   2.09, 0.003 /s/point, total 282.5 /s
# Done  96.976 %, average grains/point   2.09, 0.003 /s/point, total 282.7 /s
# Done  97.023 %, average grains/point   2.09, 0.003 /s/point, total 282.8 /s
# Done  97.070 %, average grains/point   2.09, 0.003 /s/point, total 282.9 /s
# Done  97.117 %, average grains/point   2.09, 0.003 /s/point, total 283.0 /s
# Done  97.165 %, average grains/point   2.09, 0.003 /s/point, total 283.1 /s
# Done  97.212 %, average grains/point   2.09, 0.003 /s/point, total 283.3 /s
# Done  97.259 %, average grains/point   2.09, 0.003 /s/point, total 283.4 /s
# Done  97.306 %, average grains/point   2.09, 0.003 /s/point, total 283.5 /s
# Done  97.354 %, average grains/point   2.09, 0.003 /s/point, total 283.7 /s
# Done  97.401 %, average grains/point   2.09, 0.003 /s/point, total 283.8 /s
# Done  97.448 %, average grains/point   2.09, 0.003 /s/point, total 283.9 /s
# Done  97.495 %, average grains/point   2.09, 0.003 /s/point, total 284.0 /s
# Done  97.543 %, average grains/point   2.09, 0.003 /s/point, total 284.1 /s
# Done  97.590 %, average grains/point   2.09, 0.003 /s/point, total 284.3 /s
# Done  97.637 %, average grains/point   2.09, 0.003 /s/point, total 284.4 /s
# Done  97.684 %, average grains/point   2.09, 0.003 /s/point, total 284.6 /s
# Done  97.731 %, average grains/point   2.09, 0.003 /s/point, total 284.7 /s
# Done  97.779 %, average grains/point   2.09, 0.003 /s/point, total 284.8 /s
# Done  97.826 %, average grains/point   2.09, 0.003 /s/point, total 284.9 /s
# Done  97.873 %, average grains/point   2.09, 0.003 /s/point, total 285.1 /s
# Done  97.920 %, average grains/point   2.09, 0.003 /s/point, total 285.2 /s
# Done  97.968 %, average grains/point   2.09, 0.003 /s/point, total 285.3 /s
# Done  98.015 %, average grains/point   2.09, 0.003 /s/point, total 285.4 /s
# Done  98.062 %, average grains/point   2.09, 0.003 /s/point, total 285.6 /s
# Done  98.109 %, average grains/point   2.09, 0.003 /s/point, total 285.7 /s
# Done  98.157 %, average grains/point   2.09, 0.003 /s/point, total 285.8 /s
# Done  98.204 %, average grains/point   2.09, 0.003 /s/point, total 285.9 /s
# Done  98.251 %, average grains/point   2.09, 0.003 /s/point, total 286.1 /s
# Done  98.298 %, average grains/point   2.09, 0.003 /s/point, total 286.2 /s
# Done  98.346 %, average grains/point   2.09, 0.003 /s/point, total 286.3 /s
# Done  98.393 %, average grains/point   2.09, 0.003 /s/point, total 286.5 /s
# Done  98.440 %, average grains/point   2.09, 0.003 /s/point, total 286.6 /s
# Done  98.487 %, average grains/point   2.09, 0.003 /s/point, total 286.7 /s
# Done  98.535 %, average grains/point   2.09, 0.003 /s/point, total 286.8 /s
# Done  98.582 %, average grains/point   2.09, 0.003 /s/point, total 286.9 /s
# Done  98.629 %, average grains/point   2.09, 0.003 /s/point, total 287.1 /s
# Done  98.676 %, average grains/point   2.09, 0.003 /s/point, total 287.2 /s
# Done  98.723 %, average grains/point   2.09, 0.003 /s/point, total 287.3 /s
# Done  98.771 %, average grains/point   2.09, 0.003 /s/point, total 287.4 /s
# Done  98.818 %, average grains/point   2.09, 0.003 /s/point, total 287.6 /s
# Done  98.865 %, average grains/point   2.09, 0.003 /s/point, total 287.7 /s
# Done  98.912 %, average grains/point   2.09, 0.003 /s/point, total 287.8 /s
# Done  98.960 %, average grains/point   2.09, 0.003 /s/point, total 287.9 /s
# Done  99.007 %, average grains/point   2.09, 0.003 /s/point, total 288.1 /s
# Done  99.054 %, average grains/point   2.09, 0.003 /s/point, total 288.2 /s
# Done  99.101 %, average grains/point   2.09, 0.003 /s/point, total 288.3 /s
# Done  99.149 %, average grains/point   2.09, 0.003 /s/point, total 288.5 /s
# Done  99.196 %, average grains/point   2.09, 0.003 /s/point, total 288.6 /s
# Done  99.243 %, average grains/point   2.09, 0.003 /s/point, total 288.7 /s
# Done  99.290 %, average grains/point   2.09, 0.003 /s/point, total 288.8 /s
# Done  99.338 %, average grains/point   2.09, 0.003 /s/point, total 289.0 /s
# Done  99.385 %, average grains/point   2.09, 0.003 /s/point, total 289.1 /s
# Done  99.432 %, average grains/point   2.09, 0.003 /s/point, total 289.2 /s
# Done  99.479 %, average grains/point   2.09, 0.003 /s/point, total 289.3 /s
# Done  99.526 %, average grains/point   2.09, 0.003 /s/point, total 289.4 /s
# Done  99.574 %, average grains/point   2.09, 0.003 /s/point, total 289.6 /s
# Done  99.621 %, average grains/point   2.09, 0.003 /s/point, total 289.7 /s
# Done  99.668 %, average grains/point   2.09, 0.003 /s/point, total 289.8 /s
# Done  99.715 %, average grains/point   2.09, 0.003 /s/point, total 290.0 /s
# Done  99.763 %, average grains/point   2.09, 0.003 /s/point, total 290.1 /s
# Done  99.810 %, average grains/point   2.09, 0.003 /s/point, total 290.2 /s
# Done  99.857 %, average grains/point   2.09, 0.003 /s/point, total 290.3 /s
# Done  99.904 %, average grains/point   2.09, 0.003 /s/point, total 290.5 /s
# Done  99.952 %, average grains/point   2.09, 0.003 /s/point, total 290.6 /s
# Done  99.999 %, average grains/point   2.09, 0.003 /s/point, total 290.7 /s
# 290.96212673187256 seconds 0.0034359788704889237 s per point
# 290.83279156684875 seconds 0.0034344515483620735 s per point without setup

# %%
ds.save()
